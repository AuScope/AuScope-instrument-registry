# %% [markdown]
# # CKAN API Documentation (Python + Jupyter)
# ## Introduction
#
# This notebook documents how to interact with a CKAN instance using its HTTP API from Python.
# It focuses on practical, copy/paste-friendly examples for common tasks:
#
# Read-only (no auth required): search datasets, read dataset/org/group metadata, list resources, etc.
#
# Write operations (auth required): create, update, and delete (CUD) datasets, resources, organizations, etc.
#
# Each section will build up from basics (connection + GET requests) to authenticated workflows, with clear request/response examples.
#
# ## Requirements
# Python libraries
#
# You’ll need:
#
# - requests (HTTP calls)
#
# - pandas (optional, for tabular outputs)
#
# - python-dotenv (optional, load environment variables from a .env file)
#
# - tqdm (optional, progress bars for bulk operations)
#
# ## CKAN access & credentials
#
# - CKAN base URL (e.g., https://your-ckan-site.example)
#
# - API key (required for Create/Update/Delete endpoints)
#
# Generate or copy your API key from your CKAN user profile (or ask an admin).
#
# Keep it secret (in `.env` file) and do not commit it into git.
#
# Notes
#
# Read-only endpoints usually work without an API key.
#
# Authenticated requests typically pass the key via the Authorization header.

# %% [markdown]
# # Setup

# %%
# -----------------------------
# Imports
# -----------------------------
from __future__ import annotations

import json
import os
from typing import Any, Dict, Optional

from pprint import pprint

import requests
from dotenv import load_dotenv


# -----------------------------
# Configuration (env vars)
# -----------------------------
# Loads variables from a local .env file (if present)
# Example .env:
#   CKAN_BASE_URL=https://your-ckan-site.example
#   CKAN_API_KEY=xxxx-xxxx-xxxx-xxxx
load_dotenv()

CKAN_BASE_URL = os.getenv("CKAN_BASE_URL", "").rstrip("/")
CKAN_API_KEY = os.getenv("CKAN_API_KEY")  # required for Create/Update/Delete (CUD) actions

if not CKAN_BASE_URL:
    raise ValueError("CKAN_BASE_URL is not set. Add it to your .env or environment variables.")

ACTION_BASE = f"{CKAN_BASE_URL}/api/3/action"

# %% [markdown]
# # Helpers

# %%
# -----------------------------
# Helper: call CKAN Action API
# -----------------------------
def ckan_action(
    action: str,
    *,
    method: str = "GET",
    data: Optional[Dict[str, Any]] = None,
    params: Optional[Dict[str, Any]] = None,
    api_key: Optional[str] = None,
    timeout: int = 60,
) -> Dict[str, Any]:
    url = f"{ACTION_BASE}/{action}"
    method = method.upper()

    headers = {"Accept": "application/json"}
    if api_key:
        headers["Authorization"] = api_key

    def _parse_or_raise(resp: requests.Response) -> Dict[str, Any]:
        try:
            payload = resp.json()
        except Exception:
            text = (resp.text or "").strip()
            raise RuntimeError(f"Non-JSON response from CKAN (HTTP {resp.status_code}): {text[:500]}")

        if not resp.ok or payload.get("success") is False:
            raise RuntimeError(
                f"CKAN API error for action '{action}' (HTTP {resp.status_code}):\n"
                f"{json.dumps(payload, indent=2)}"
            )
        return payload

    def _looks_like_post_required(resp: requests.Response) -> bool:
        if resp.status_code != 400:
            return False
        body = (resp.text or "").lower()
        return "invalid request" in body and "use post method" in body

    if method == "GET":
        resp = requests.get(url, headers=headers, params=params, timeout=timeout)

        # Some CKAN/proxies require POST for Action API even for read-only actions
        if _looks_like_post_required(resp):
            # try POST JSON
            resp = requests.post(
                url,
                headers={**headers, "Content-Type": "application/json"},
                json=params or {},
                timeout=timeout,
            )
            # fallback to form-encoded if still complaining
            if _looks_like_post_required(resp):
                resp = requests.post(
                    url,
                    headers=headers,
                    data=params or {},
                    timeout=timeout,
                )

        return _parse_or_raise(resp)

    if method == "POST":
        resp = requests.post(
            url,
            headers={**headers, "Content-Type": "application/json"},
            params=params,
            json=data or {},
            timeout=timeout,
        )

        if resp.status_code == 400 and _looks_like_post_required(resp):
            resp = requests.post(
                url,
                headers=headers,
                params=params,
                data=data or {},
                timeout=timeout,
            )

        return _parse_or_raise(resp)

    raise ValueError("method must be GET or POST")



def _truncate_str(s: str, max_len: int) -> str:
    if len(s) <= max_len:
        return s
    return s[: max_len - 3] + "..."

def _format_value(
    v: Any,
    *,
    max_str_len: int = 160,
    max_list_items: int = 6,
    max_dict_keys: int = 6,
    _depth: int = 0,
    _max_depth: int = 2,
) -> str:
    # Prevent overly-deep nesting in prints
    if _depth >= _max_depth:
        return '"..."'

    if isinstance(v, dict):
        items = list(v.items())
        shown = items[:max_dict_keys]
        parts = []
        for k, vv in shown:
            k_json = json.dumps(str(k))
            vv_json = _format_value(
                vv,
                max_str_len=max_str_len,
                max_list_items=max_list_items,
                max_dict_keys=max_dict_keys,
                _depth=_depth + 1,
                _max_depth=_max_depth,
            )
            parts.append(f"{k_json}: {vv_json}")
        if len(items) > max_dict_keys:
            parts.append('"...": "..."')
        return "{ " + ", ".join(parts) + " }"

    if isinstance(v, (list, tuple)):
        items = list(v)
        shown = items[:max_list_items]
        parts = [
            _format_value(
                vv,
                max_str_len=max_str_len,
                max_list_items=max_list_items,
                max_dict_keys=max_dict_keys,
                _depth=_depth + 1,
                _max_depth=_max_depth,
            )
            for vv in shown
        ]
        if len(items) > max_list_items:
            parts.append('"..."')
        return "[ " + ", ".join(parts) + " ]"

    # Scalars / everything else
    try:
        s = json.dumps(v, ensure_ascii=False)
    except TypeError:
        s = json.dumps(str(v), ensure_ascii=False)

    s = _truncate_str(s, max_str_len)
    return s


def print_key_vals(records, num_keys: int = 10, num_records: int = 5, *, show_record_index: bool = True):
    """
    Prints records in a JSON-like style.
    - Shows only the first `num_keys` keys per record; prints "..." if more keys exist.
    - Shows only the first `num_records` records; prints "..." if more records exist.
    - Values are abbreviated (nested dicts/lists, long strings) with "...".
    """
    if not isinstance(records, list):
        records = [records]

    total_records = len(records)
    shown_records = records[:num_records]

    for i, rec in enumerate(shown_records):
        if show_record_index:
            print(f"Record {i}:")
        if not isinstance(rec, dict):
            print(_format_value(rec))
            print()
            continue

        keys = list(rec.keys())
        shown_keys = keys[:num_keys]

        print("{")
        for idx, k in enumerate(shown_keys):
            v = rec.get(k)
            k_json = json.dumps(str(k), ensure_ascii=False)
            v_json = _format_value(v)
            comma = "," if idx < len(shown_keys) - 1 else ""
            print(f"  {k_json}: {v_json}{comma}")

        if len(keys) > num_keys:
            print('  "..." : "..."')

        print("}")
        print()

    if total_records > num_records:
        print(f"... ({total_records - num_records} more records)")

# %% [markdown]
# # Read Records

# %%
def list_all_packages(
    *,
    page_size: int = 100,
    start: int = 0,
    include_private: bool = False,
    api_key: str | None = None,
) -> list[dict]:
    """
    List ALL packages (datasets) using pagination via `package_search`.

    Returns a list of dataset dicts (as returned by CKAN).

    Pagination:
      - Uses `package_search` with `rows` (page size) and `start` (offset).

    Auth:
      - Public datasets can be listed without an API key.
      - If include_private=True, an API key is required and must have permission
        to view private datasets.
    """
    # --- input validation ---
    if page_size < 1:
        raise ValueError("page_size must be >= 1")
    if start < 0:
        raise ValueError("start must be >= 0")
    if include_private and not api_key:
        raise ValueError("include_private=True requires a non-empty api_key")

    all_results: list[dict] = []
    offset = start

    # --- pagination loop ---
    while True:
        params: Dict[str, Any] = {
            "q": "*:*",
            "rows": page_size,
            "start": offset,
        }

        try:
            payload = ckan_action(
                "package_search",
                method="GET",
                params=params,
                api_key=api_key if include_private else None,
            )
        except RuntimeError as e:
            # Provide a more actionable message for common auth failures
            msg = str(e)
            if include_private and ("403" in msg or "Not authorized" in msg or "authorization" in msg.lower()):
                raise PermissionError(
                    "CKAN rejected the request. Your api_key may be missing, invalid, "
                    "or lack permission to view private datasets."
                ) from e
            raise

        result = payload.get("result") or {}
        results = result.get("results") or []
        count_raw = result.get("count", 0)

        # Defensive parsing
        try:
            count = int(count_raw)
        except (TypeError, ValueError) as e:
            raise RuntimeError(f"Unexpected 'count' value from CKAN: {count_raw!r}") from e

        # Append and advance
        all_results.extend(results)
        offset += len(results)

        # Stop when we've fetched everything, or when CKAN returns no more results
        if not results or offset >= count:
            break

    return all_results

# %%
records = list_all_packages()
print_key_vals(records, num_records=2)
# Out:
# Record 0:
# {
#   "author": "[{\"author_affiliation\": \"The University of Melbourne\", \"author_affiliation_identifier\": \"https://ror.org/01ej9dk98\", \"author_affiliation_identifier...,
#   "author_email": null,
#   "citation": "G. Beardsmore (CZO) Heat Needle Data. ",
#   "creator_user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "credit": "",
#   "declaration": "declaration_accepted",
#   "deposit_date": "2025-06-20 04:10:39.055978",
#   "doi": "10.82669/ncci8koo",
#   "elevation": "",
#   "embargo_date": ""
#   "..." : "..."
# }
#
# Record 1:
# {
#   "author": "[{\"author_affiliation\": \"Commonwealth Scientific and Industrial Research Organisation\", \"author_affiliation_identifier\": \"https://ror.org/03qn8fb07\"...,
#   "author_email": null,
#   "citation": "Stu WoodmanTest ISO19115 001. ",
#   "creator_user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "credit": "",
#   "declaration": "declaration_accepted",
#   "deposit_date": "2024-06-24 01:27:41.145582",
#   "doi": "10.82669/cbqpep5i",
#   "elevation": "",
#   "embargo_date": ""
#   "..." : "..."
# }

# %% [markdown]
# # Get Record by Title

# %%
def get_package_by_title(
    title: str,
    *,
    api_key: Optional[str] = None,
    include_private: bool = False,
    rows: int = 10,
) -> dict:
    """
    Find a package (dataset) by its *title* (human-readable), then return the best match.

    Strategy:
    - Uses `package_search` with a quoted title query to prefer exact phrase matches.
    - If multiple results match, prefers exact (case-insensitive) title equality.
    - Returns the dataset dict (as in `package_search` results).

    Notes:
    - Titles are not guaranteed unique in CKAN. If your instance allows duplicates,
      this will return the "best" match, not necessarily unique.
    - For guaranteed lookup, use the dataset `name`/`id` with `package_show`.
    """
    if not title or not title.strip():
        raise ValueError("title must be a non-empty string")
    if include_private and not api_key:
        raise ValueError("include_private=True requires a non-empty api_key")
    if rows < 1:
        raise ValueError("rows must be >= 1")

    # Quoted phrase search; escape quotes to keep query valid
    phrase = title.strip().replace('"', '\\"')
    q = f'title:"{phrase}"'

    payload = ckan_action(
        "package_search",
        method="GET",
        params={"q": q, "rows": rows, "start": 0},
        api_key=api_key if include_private else None,
    )

    result = payload.get("result") or {}
    results: list[dict] = result.get("results") or []

    if not results:
        raise LookupError(f"No package found with title matching: {title!r}")

    # Prefer exact title match (case-insensitive)
    title_norm = title.strip().casefold()
    exact = [r for r in results if (r.get("title") or "").strip().casefold() == title_norm]
    return exact[0] if exact else results[0]

# %%
record = get_package_by_title(title="Test Instrument 02")
print_key_vals(record)

# %% [markdown]
# # Get API Token Names

# %%
def get_user_id(*, username: str, api_key: str) -> str:
    """
    Resolve a CKAN user id from a username using user_show.
    Requires api_key.
    """
    if not username or not username.strip():
        raise ValueError("username is required")
    if not api_key or not api_key.strip():
        raise ValueError("api_key is required")

    payload = ckan_action(
        "user_show",
        method="GET",
        params={"id": username.strip()},
        api_key=api_key,
    )
    user = payload.get("result") or {}
    user_id = user.get("id")
    if not user_id:
        raise RuntimeError("Could not resolve user id from user_show response.")
    return user_id

def list_api_tokens(*, api_key: str, username: str) -> list[dict]:
    """
    List API tokens for the given user_id.
    Requires api_key and user_id (your CKAN requires user_id).
    """
    user_id = get_user_id(username=username, api_key=api_key)
    if not api_key or not api_key.strip():
        raise ValueError("api_key is required for api_token_list")
    if not user_id or not user_id.strip():
        raise ValueError("user_id is required for api_token_list (your CKAN instance enforces this)")

    payload = ckan_action(
        "api_token_list",
        method="GET",
        params={"user_id": user_id.strip()},
        api_key=api_key,
    )

    result = payload.get("result")
    if not isinstance(result, list):
        raise RuntimeError(f"Unexpected api_token_list result type: {type(result).__name__}")
    return result

# %%
res = list_api_tokens(username= "ckan_admin", api_key=CKAN_API_KEY)
print_key_vals(res, num_keys=12, num_records=min(5, len(res)))
# Out:
# Record 0:
# {
#   "id": "CgrDv9EuiupEdjFuCN96thMtcvENRu4u7pdwnX3GrTY",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-06T00:43:54.909777",
#   "last_access": null
# }
#
# Record 1:
# {
#   "id": "RQnRrSFj-1FsRXlEAtIN70mW0e1u7E2WyfFaOp5baRU",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-19T04:32:23.529843",
#   "last_access": "2024-03-19T10:39:59.324042"
# }
#
# Record 2:
# {
#   "id": "yirdop13NfLEz1PP1dfI_u9DsdXn3O1ZvsSDr5PbxWs",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-06T02:43:28.140492",
#   "last_access": "2024-03-06T03:04:02.927656"
# }
#
# Record 3:
# {
#   "id": "H_4MQFYxHe7wAD86qJUNwvQv9ar7c_7ODAL1SkeTQkc",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-06T03:11:48.140155",
#   "last_access": null
# }
#
# Record 4:
# {
#   "id": "W3I9JPvzDfJuCHxfOiF_aoCWZHmwQunYBUiUNHTTksk",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-19T22:04:34.736749",
#   "last_access": null
# }
#
# ... (1620 more records)

# %% [markdown]
# # Revoke API Tokens

# %%
def revoke_api_tokens(
    *,
    api_key: str,
    username: str,
    token_name: Optional[str] = None,
    dry_run: bool = False,
    limit: int = 10
) -> dict:
    """
    Revoke (delete) CKAN API tokens for a user (by username).

    Your CKAN returns tokens with fields: id, name, user_id, created_at, last_access
    and api_token_revoke expects payload: {"token": <token_value>}.
    We use `id` as the token value to revoke (common CKAN behavior).

    Args:
      api_key: required (Authorization header)
      username: required
      token_name: if provided, revoke only tokens with this exact name (no prompt)
      dry_run: if True, don't revoke—just show what would be revoked

    Returns:
      dict summary with per-token status.
    """
    if not api_key or not api_key.strip():
        raise ValueError("api_key is required")
    if not username or not username.strip():
        raise ValueError("username is required")

    tokens = list_api_tokens(api_key=api_key, username=username.strip())

    if token_name is not None:
        name = token_name.strip()
        if not name:
            raise ValueError("token_name cannot be empty/whitespace")
        targets = [t for t in tokens if (t.get("name") == name)]
        if not targets:
            raise LookupError(f"No tokens found with name: {token_name!r}")
    else:
        targets = tokens

    if not targets:
        return {"revoked": 0, "skipped": 0, "details": [], "message": "No tokens to revoke."}

    print(f"User: {username.strip()}")
    print(f"Tokens found: {len(tokens)}")
    print(f"Tokens selected for revocation: {len(targets)}")
    print_key_vals(targets, num_keys=12, num_records=min(10, len(targets)))

    if token_name is None and not dry_run:
        confirm = input(
            "You are about to REVOKE ALL tokens listed above. Type 'REVOKE ALL' to continue: "
        ).strip()
        if confirm != "REVOKE ALL":
            print("Cancelled. No tokens were revoked.")
            return {"revoked": 0, "skipped": len(targets), "details": [], "message": "Cancelled by user."}

    if dry_run:
        print("Dry run enabled. No tokens were revoked.")
        return {
            "revoked": 0,
            "skipped": len(targets),
            "details": [{"id": t.get("id"), "name": t.get("name")} for t in targets],
            "message": "Dry run only.",
        }

    details = []
    revoked = 0
    skipped = 0

    for i, t in enumerate(targets):
        token_value = t.get("id")  # CKAN expects field name "token" in revoke payload
        if not token_value:
            skipped += 1
            details.append({"id": None, "name": t.get("name"), "status": "skipped", "reason": "missing id"})
            continue

        try:
            ckan_action(
                "api_token_revoke",
                method="POST",
                data={"token": token_name, "jti": token_value},
                api_key=api_key,
            )
            revoked += 1
            details.append({"id": token_value, "name": t.get("name"), "status": "revoked"})
        except Exception as e:
            msg = str(e)
            # common permission-ish signals
            if "403" in msg or "Not authorized" in msg or "not authorized" in msg.lower():
                details.append({
                    "id": token_value,
                    "name": t.get("name"),
                    "status": "failed",
                    "error": "Not authorized (403). You may need to be the token owner or a sysadmin.",
                })
            else:
                details.append({"id": token_value, "name": t.get("name"), "status": "failed", "error": msg})
            skipped += 1

        if (limit is not None and i == limit):
            break

    print(f"Done. Revoked={revoked}, Failed/Skipped={skipped}")
    return {"revoked": revoked, "skipped": skipped, "details": details}

# %%
revoke_api_tokens(
    api_key=CKAN_API_KEY,
    username='ckan_admin',
    token_name='datapusher',
    limit=None
)
# Out:
# User: ckan_admin
# Tokens found: 1625
# Tokens selected for revocation: 1620
# Record 0:
# {
#   "id": "CgrDv9EuiupEdjFuCN96thMtcvENRu4u7pdwnX3GrTY",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-06T00:43:54.909777",
#   "last_access": null
# }
#
# Record 1:
# {
#   "id": "RQnRrSFj-1FsRXlEAtIN70mW0e1u7E2WyfFaOp5baRU",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-19T04:32:23.529843",
#   "last_access": "2024-03-19T10:39:59.324042"
# }
#
# Record 2:
# {
#   "id": "yirdop13NfLEz1PP1dfI_u9DsdXn3O1ZvsSDr5PbxWs",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-06T02:43:28.140492",
#   "last_access": "2024-03-06T03:04:02.927656"
# }
#
# Record 3:
# {
#   "id": "H_4MQFYxHe7wAD86qJUNwvQv9ar7c_7ODAL1SkeTQkc",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-06T03:11:48.140155",
#   "last_access": null
# }
#
# Record 4:
# {
#   "id": "W3I9JPvzDfJuCHxfOiF_aoCWZHmwQunYBUiUNHTTksk",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-19T22:04:34.736749",
#   "last_access": null
# }
#
# Record 5:
# {
#   "id": "eRVQB-Nk67qxRvOSIEqGk9iAsw6gpaNyGpQfmCfpPC4",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-20T04:51:04.230227",
#   "last_access": null
# }
#
# Record 6:
# {
#   "id": "uqXyMZBFQgcHavu1w6xuXcfD0TZ3bM_SwbufKB1eIvo",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-20T05:42:26.831113",
#   "last_access": "2024-03-20T06:24:17.322798"
# }
#
# Record 7:
# {
#   "id": "Y7wxDvB5rBT1MZjiyy7nAe4chfFr6s7aIO4-cOtHu0s",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-20T23:04:16.727374",
#   "last_access": null
# }
#
# Record 8:
# {
#   "id": "DsoIYiJTtVbf33aoQz9yrR0YFBNz69Vfs0_Nfx1NY-U",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-13T09:10:45.843985",
#   "last_access": null
# }
#
# Record 9:
# {
#   "id": "m1dM_42aV4wGiGun5Z2ybGCsVjnpcVjrSf-BGu8eH_4",
#   "name": "datapusher",
#   "user_id": "8df5712a-8480-48e2-b1f4-397c9cc48a3f",
#   "created_at": "2024-03-13T09:31:05.045915",
#   "last_access": null
# }
#
# ... (1610 more records)
# Done. Revoked=1620, Failed/Skipped=0
# {'revoked': 1620,
#  'skipped': 0,
#  'details': [{'id': 'CgrDv9EuiupEdjFuCN96thMtcvENRu4u7pdwnX3GrTY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'RQnRrSFj-1FsRXlEAtIN70mW0e1u7E2WyfFaOp5baRU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yirdop13NfLEz1PP1dfI_u9DsdXn3O1ZvsSDr5PbxWs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'H_4MQFYxHe7wAD86qJUNwvQv9ar7c_7ODAL1SkeTQkc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'W3I9JPvzDfJuCHxfOiF_aoCWZHmwQunYBUiUNHTTksk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'eRVQB-Nk67qxRvOSIEqGk9iAsw6gpaNyGpQfmCfpPC4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'uqXyMZBFQgcHavu1w6xuXcfD0TZ3bM_SwbufKB1eIvo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Y7wxDvB5rBT1MZjiyy7nAe4chfFr6s7aIO4-cOtHu0s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'DsoIYiJTtVbf33aoQz9yrR0YFBNz69Vfs0_Nfx1NY-U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'm1dM_42aV4wGiGun5Z2ybGCsVjnpcVjrSf-BGu8eH_4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_U8J6Fi6T2JI_LSCDCkqAUcIYNOnBI5tczI29P0ArBk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hpvTP8Zr8vK4D9kx8WtCCQDKqn3nIM8zTqedGiJUb6o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'DSS5TstT53FSdZHsrWYO9kHI0ZyvDL5tpiPGxWwPy28',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zECpVuhMAXNwJN4Udtg4LVumYwU2XrxK-8QahdA49E8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'F0hk2RB2GNMgKPyLIK_eExF4lyl5y7OYmuKbXKYU5OI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3dGHBwz6DROfGpXGwQQxyqh7Qk0EMqsNVJ48Yi0hj-I',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hg_wR8oJVenFH_PeusgtE2Fn_mOKB7jbe006YAa1cv4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'wE48d0xy_gtfuKgYvWP4lrjo7qiUDeceUMpQG5KemJE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'B_M4_b7u1UcE7BNV03AGtTiHbff7jMari4NpPhZoNOI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZTs3FBSKCdmh9PkYhcdWfYr2_5fQsL7jrPDOHR2X8h4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'p7aeA023Rg2si3P7WPr-0cfdl0YlYVRPxV8ovfvb7yI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EvHKsFdfkQSSx9KM8_rLMk2PFh2Q1VFtZoL3N6COjhM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jkNvhum7dXvNoGQacIgIRwQppNg3jW0LLfFSZRAosCo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '-tVuigF4fReYPBFdfLlFUBTVKbVHWQ7puPJatzHPWZE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'r2NgXeLhuuhNPNF-K45iCk3DwavNAG1LpOxrk-8P70I',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'oZdUTw1QxmrVOK0yfvmATw19xlPJF5PUr-V9_tWAD7M',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '01nl2rRzzn63i-bSePsbbZfwARvyvIoAYjfwuFmZDPc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hIk8-efG3RjFNFOL1zIm7GAtobwttm_1GZuFdkYKgns',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Nh_SJHcx76sl80XNlLkHOv97-38tJac4OYOtXgNvCYU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2k74F-ByrSd-9l1RtkYxPA1l_sY0LR3jAXhVgLHq5E4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZGB2VnqUIw0J68VYdQMlx3qw3rygb4b124zubO8vPHc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'NSRB_xi99ZW4GbzVOJPrJ-5V4UqhJozTbaAf4eUVjFk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ppo7WLIHvm4nEjJY1zkT_y7ZQJLOH4xYqoYQ7gJWnlU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'rnvz_HHn6WeToe5LqCmrLIVp_lBqTbg5eVo9r8rUp_Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'l0h5kylZYDSFRpwglxO4peOGHGtdfWtR1nADiOmNcBw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Jtu3c1TxJ3GiBmZfBhZv6IGkMj32A-sTavH4ZBJW-HA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qlc6ppp-cFseP0i3ZXwjjBCO97Z7nQTh-uKyeS_a1tw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zbk--jkd795-EKPyJhFtpkgdnTtrnIYhZ4QD_B-q7w0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '65UOfHbM2Nr6NczQfm6Lg4XFhw_Tg4vpw3C3Aznle58',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'MfZIEGExbM5NvMCCsNaXowbLJdwukKcognNMnKRJCB4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EHA16mF1rybodQ12WyjkjXBdOrQQbII0xPsv06hqEMU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 't-2ggOsPSPyAg1gg-0rjcJ8IpAZ8vP_pp0XjonPXueo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ERu3DzokM9cqfZNCAtLtTFXfXuRh5AqaSA_Am9lFwW8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_5xnMLCe0vH1k7ffYQnzRzWN_XjjRFgTdPLqLDzhXPk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vSUsQZhneiZz5KwzeASJ_7zzSbPCOJ_gJchTcbns014',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WG4NfcSyQeyDgOiJ2beGS4o3BFhBjGC3JA4BvjptjX0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'MMbz3fAPpqFfWF2QoD3I62HMfxVJXFDaWy6IAh3Oq_Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '8UjooJTg3p3mXAhT6rCViPvMLrHG0iXUYjNryT89p1A',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jkU7kNRqPDvfKeDd0wgpjhOEtMObjlrWv4wBPuq9jXY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jc8Sb0YIQste92ha_fCl1WFMZrndl5_lSuZB1hM6fng',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5GnwnVJ7DF5FBJMLvhW8gHIWgeuY9TIHHFScGHmswx4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'mRQtLAVr2jii-OWI18rJ8i2BJ12T9Eh5PPyw7oWHvL8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'A5sdAALaBwM4LTJpkYAGttRE__0YXsOx7_NoEpovAvI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cexTcIIedtBmZj7O00C5HNbMXRXjROQtqkPIRxL4oq4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VhdjWkvl_2G1ZT4eBKLb_kkchkAPUwAWFPZ2PoHCWvE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9tBp6ct677i0JfWrWtDHCALF7XiQuHtMAxo0Th3H8Vo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kQd8cNMI_pOl6vX7TuuJYskJlaIMPSAYhp0mdorQh0U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'S5OJYXn5a1VFYRoguuauElgUDqZ90nHtF8rBQdbRZRs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '6i83cehKdd_gAHnuLWdV7hBClFik3UyZO5KrXiSCbEA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'B3iVLoopVafHvhK_JLy7dyNrnyRe-KWtXm6c2SmHU4k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5iQxnCTMtKbc3qjRlc2MPlr8ENPFUZ1SygDn7RYiBLo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'UQBLjVQu84xyoDpblD-EOLiYnsSL9RGH5MZja4JL3PY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'pYOW-pere3thBsZaCKeX2SKZE8LCmJmr3Sk6L5ehRGA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'UHcU5QedaxMG3wFqzzm2q9aGviXB6HHrvx8Nr9djYVc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'noFnxn9yJo4UK2rl6E1bpvhfMnHsY1FQylTcejZwIFQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bstyisRYHwV0iJ7qPIs7dHo0OVGTgvtuXJU-6u4Jjgo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '11-8eFN8tq10odFHtGPk-1cyiiJF1oZZwAu0R-VkFfc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2FTCuU5mZrm87mawjdw46268_rB4ijiWiwGKZWey9sI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zXaFA_ckcgql9ygMBCXeGMqLzR8tFzQmLT2cQGcDAWk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'm5bIxPURVeqiN0r5qKYwOEo-QRLh5ckBmZhGQd2ihGg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vnxnCHR3u06XWgXIewHB61LeOnnkgeBtN8N1KCpfb7k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'IdhaUxFKDwaNRfvuhbwp38FFMROffpnaxZuhAuRIlXs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WUDl5HWTqgg38n5dF4AM_kHY8kx9DaFDX0G9qU7wXSM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VWv-zB3woakBKFJxFVHxgwKJTTGIkOI4dG1bU-q6i64',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Qdwm8XVt8V02N_ebVxOW7MheIBSc2FcrLSU-BxD5nqg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'N59hS_ZRSDTdCZ5OhAT90KKz_H38S6FIjwncxYEgoU8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9xe71yeXQ7JmuIvphwngKgdbc9CrIH9hMBGQrGI1umo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'g1ZRCjjUx66IZ723zKQLf-1Cjbsyhjms3gNemHcstX0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vafsB_WV6NTYIw1tLfb-EUu4z7sDoO0FVCJ1B90aul8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2nR8RciTKjPZ20Ga34A7HWP_ovCfCZJ00MoaXzwDBrE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PaQO8J4aPRbMPOmnM0B-1wHFP_RWhoS3dxtfc8LyElE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5_nhuCE5_FgY1MQlFaSMvEWiZMbesjFwCMQvdV-hDx8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '--vyD8kjHr0pgYk-WP3Ml-kcTIgekC5u3HXaMld4xjc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ceOuPU5eFIos3HBLXstm8kE3ZAVwDkdeapu6Uy6lumE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Ni1gDEJTsaJjzsbGQjxEsz0-RVU2eUNbuk2M90BKEyU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'e-HUAGG320AarcOZGIup1FufQemJCelm3KU5kAaeHxc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'xT3-JVCeiOGFHFQbtDFiC_TN6MwihwFyhHQMNsW2yr8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '77Ku8YrSDgI-YeGVkMO8Y2rJ8P-185OwppIyb4fFwiw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FzOddVNcu0uj6VIERcCHDuxMze0NmLORhDmHmaDy614',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jdFXVm7w8rFTPIM_dZX72HRkJBzRhRjnwxzjM0kt12E',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'w1J9nTfxRYpIX3_ChgNZORJ79oY6cVKIFBuEQjfjGWo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'W0kpYBgRUTC3RFnTe5MAfQ-FBqArbPUtPUkSeZ7Acno',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QOiMRrD1Y04TdmuwJC6-Ex7g5uAPopjebOjWi3hUpp0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'NgMdUkY0y3MLU6uhP3JSI1gAET-a-Ie3ATleroHaceE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9aoJuvxp6N_oR0qRwX96I6pcniBvh0bQ6kk0Vk9ddB8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'G_BA7qctU3-XnCQRm-vE2BwDw9BenpxlPCku_C71GRA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'etchC8jWcj5lmd1SCUvuZJojf5smmgHDzNsgjiKfn2o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'lPrLcldOW6HEPQ3d67HQSMVrJ3XTN90qKkcLPNqKirc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fJ2NkzWPTIeq4SKmQZsgvK4P3HR1xyGzsVU2BSvVxVU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QnFeRjT3sjNIBie8ybe8RFO_n3b691elZIX93bqHe34',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '8Xj2VCBOTW0uoStclYh_vuI-JdpmoioD243zIOWZ3Ho',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '8EzpDOftRsQGDYehx8wnU1jvbIOUvLorbMYp1teXVHA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'woY7mV2G2CDK1gbA7Hr4KI1nav5iqKqKzbOyKEGu1Ys',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nAgaLYBrE8FO7EOVpOiWYdk0GfcCaxPjwntjRnSxbHQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zY4bb0og-KyF6uW-l2A34TcCV42OpJVyiuFwyiWhtrQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yOR5XtIlgR1Rvyvudq3mdGp6jNUK1cLKYWja6ZYHT3Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'IFqgQMPKCE2PshKr-IqOynC8-6Ak7k_19a77FiqymYk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'xrDb10yYWSF4PKD9OE1hav6qOv3PwA1ZrbMJDu5siSc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'A3xZdLUGuPT_DT3jc0Ls3wgXNb-EiBrw6nRVrOPq2EM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_KIwv1zjbdnGigdL-z1VobvBkBuOX8Tl6HXAn31pQ2Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Mf6Nuyaih85U0YjH-ByvV0cZAuf1hqrgVIm32B8jQEU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9LGd5PM5j9itag6Vy2jip8xZcPv1Hf55PBXj6agaG7k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5_h-d6JhkVjDofOQarReQAlzVKo6nUSB-1YmwuC_kGg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ap6RNzstrUGbZTNyy3SCNxQq-uQJldfZUsLJoFeHI_M',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nedRZ-UN0sE2nmiKHsDGTXgMQ-ze0rjSUz6Jlu4b0aA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9kcOgV8e3W6b0CuvVJ1hH8_QGPpfyfp2EqkgxYukVJE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QXZMKWHEGv5x26E4ZnUjATV85dhveYpqZ6fobBCUPH0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'UYx6-TfQB8s7dHyMXr3CYz3KrZ8tEXcQRJ4BiHrp0Ew',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'f4QGhHil11JXzd8INtB6DugyOZzJusk0GRx1xwKXaj0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'wHhjdZEUBcrOoOCOHVnpUEYSzhU9z6c9kzrFxZh6PoY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ojMXlzwlAXZlYhTNhXa-s2Vs2NezpKdi_DfwYH1yviE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yvhQ06c_Qq7eTrwQyrInOrtyU-EefGFW6Nrf_DXyOb0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5pxHGVbdRq2u7RKWn8Ss1E1qS97NGI3c5OLzQXLp1cI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OY1ZztH0GaX_SeYWaQ_WHMG4IKNFQvzILJXU-Ykg7-0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'HCs4CWokbfscbBHNZjQXwLgvvyOi84mEEHRUWugiIEM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'YayBrMRWmiOIeTgOkNpY6rCJPi3btmem3hXhgBJcgcQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZAgfGSIceq5TuXZucR8hW2N-WSYohpd6QvRRV8Fv7ms',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hb9SToIsnxw2v0BZ0ZYWkaEZouCybC3ra-9jPLk14jQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SLn7nXZTDoRRG5OZhCV_1ytF-cEOOrYOTXQSa0W_8zI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_W-0wsvy6Dkev2SmuMAJv5rRJ8RxuRSLKIE-iYAEAh0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qRbZKFdZvTm83fZDOkjHlCfr4b8hZ4wJVbiP6vJlDbQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5VhFWRg29A2ybXZ02JYRpg8oztX_ISeHWK7Xc5HkNgc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'KiwpGCXN8YvlyHmAkLejMyA2iRw2tlhVwNleZxLgfik',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'h5JPYEJHZZdef3yn53C1PswCteBSDAEy_SLrsGTEBxg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'j-Wb1xLXgcIc1cyLCkSWcj1AveyzxWdSk2fs_BguITE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'oO5wzTnJ7Z4bjPuTeNu2Fun3EAwSyTBB-vvhm6Rjy6k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'x3S17_1_x_HL-c_etu1Ye9SqLJJEBqHU5WvxdBac4S0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Toe6KBSNRFJLpY-DC5Rtwjg3_33yo4qreWo79pgYfxE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bO7qrerwmr9_zp_M1a3Kz7OZdPoUcpKq7OgfBlyj41U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'RODYLp4uzcCAE8K8idpe1SuamZz-j1R1-IjacjvMtpg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'LV4S_o3c5r30OmGbl8jZ7NlL-tKZfNe7yTxO15TTA_s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zMz_mgtYnKsGPpv1cTPjfOaVsSwRpHt9dTbyvYZltm0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '8grpMLsxMChGXoo3yEhAeAsIojkvYQ6EQHV6MTDN4pY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jcj_7jqWUizCsqjLmWPjm-COW7OlpAzSmWRP8IXqta0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cCQutb8SdLSVo6-JmWkt9wscrvUnecMhjT215O4R6W4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WY8kcfaGaON77D8H_oZsFuZZY3G30kl4bLAskZvnx8Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OoKQJnOyt7B8rAapWUOC79urmXVecMDZkwc7LPzamCE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'w1z6mI7z2cd68zLYHe4yM5Pw9gBOBjJ3IXU1eUOscVI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'eI1xvnjXelpEyTtmqFqFpTXOZCYyGY506-jlahT4iuc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cvR_KVG6tIBe__DCI5aW-mfwQUxhz3s898VKfbFFvSo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VfSotCsWujDGNXx6MYuswG8maNYl0nfWI8QvdAH7IrI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'BH9u8YPvahGp5G-2o235IbXNxGg6Sldpk1xTjhR3tjs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 't-03HmqyZDqk4Gkdg1qUVnuT3b6_OSbN1fd1yYvt8R4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '1sZ0dzuufZL_Ft7QZW8G0qWhSMh4kCukJ3_EEmajCmw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'MDd3pYWc3JAoOgtOADhcya1_TLhnZFDR4pawhppLAMo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FpUFBZNXLd_Iad1OhbrkzMniFpeXDNHc6d1JSH22mjY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'uE_FfRS36vjHahZhgY0z4AxeOrDd7g8eHsmypJCsvec',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WtIIzMmN97jP1jKAHATJpGadOoNgceqdxwiIe61FyOE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sqc278IujVEXS7CBWhFTk71GoDkwl0pWRs8EVMl2jBM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'YIAgMOUuzoYlpKR_sEA5QSRk9qVH30DpnYp3bJuAz-s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OTkPsCl0U7WYAvGPZz8wzPyvIDfEjdSb4I-9WraIH74',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'aHPw8yvbzXoV51uqEEfxlcKz2-BuBVjg8HVsA-GtQ4o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3V-whrmKAKJwdxrIgSEgfba3zUJocnuTQ4yAWe1qf9U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZQk0D89NaDc8NrwXjtRtKuyfr_8g54ZKaZj6lKeGt3E',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'DK4AKZ3oMNk9gjLjacb9tdk23p_tN2B6mbUbp3XBSok',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Ddd9SXoy-ETb-R0PfP50hst8tCCZzm2iSjWvrjmEd6g',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'BK044BbTfcfsKKOM9RCERl0AvMbtbE5A4hH8G6GPSB4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3YOndwNtAhOcEYRXBNS7ibtmyjNe-ZaTRtX0E4AahYE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cu3iRUATnRD-Fpf1Q4C9vw5ah6Da3KIK9O3dLulqtuU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZokTgnsCukUITBSGCU_N3AV5RVmU2o1AopqV3UbKVn8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0fak4XQjw-qJ3Sdv_TvrqxClFp1536HZV-9bSV6KB4c',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'z6JsNac7-pytAHmNdmxAhYg8j8wXUK00Q9JW7Plian4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'HynmziiNVvehq-Bnhz6tOEwOBlDrbZsjEDOs8nwvJdw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Mkj_MQXmQVy2TRH_DIcmSUYImOn24uaaLaXyHcfAytc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'YLhUDdKYpHe0CduUgbpgT3QeW9trIAgO1WsRxsRj19o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '59_ODjXFbCYrw5gOPfeWnBxsrMqSWmJ2Gn3Hp43NKpg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'MaD3lFA6U5YLNiMZ5r6A5-yp5ujw1UfDiJSoO2392YQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'LtUPnMvuHwCaBtVPmEqeFuCBDJ8RMO1GABgzFn4_j-c',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2dDSnyoMe6BUFFkpLy-fEX1tokieHq-lmgXTXsSoXyQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'elsEHWyLV1gWIEPPvxm_8AKOdNegmxaSTIicz5pL_QY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9bNiRnS3pSK8PVuIjV7SAmDezC4afDXsKuK02QWucAw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FBIK8szXn9UJHZlw4zUVRWvWzGhXLlGmPuwYPApYvqA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'JPeDyOLDsq0FqrSFVkzxn-wCUPnirdAe8YeVRDSROFo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bheyxx5wRLmG1fsRRiRcVvaeHW3kldPA97yMqmJ2mcQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Cb0355rfg7eNBYFcpMwnPD95MRaYv8ES8T-CQz_v960',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'n76cvAs1166BbJnOhS2kIjzTR5VQ6fBBn8SbitumiiI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'O6TCYaJ9DRzufrd4fW3QhAko1Yxb-j5NLhUIx-oMlec',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qDHuBty_6QLeRJ6sI51FcnUZ4vnVOmq3XJyiFXamjuM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'mI4ACtnD_fJ47dny80mTbNHiS0ZMCc86aIw_ytRdWCA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ehjv9C6dfsu2tboQcywzM0cpTm5Je4iR4wBZdW8B55A',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PG0rsZFxc6QGyYjDnUEqYjNFOx3HLQFMyR72W2jX0zY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_1Pr3LB3VK8nQ-lEyU1wm6oCWmN_JWT8baiaf5sfTNY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kxpErv-z2ZXfrD8n-ENyZgWsTIgkaVRKPybqLPOi6bQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '69dAdDScyTqi0tHs4167XFHoPe52RNH8Dotjouv7pCs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'v0zU3ZVcSIZA-NNtuNT5QmVH1UvJZ6395L0tU8g1sgo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'DCKa5_tr-PaEgtOR-8m5HnLIgbWwV9nK4GCX8OHDjUA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 's-BrJVOCfADLrXngBn150SJ9jJ4DhjxnGVw0Kr-X9C0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fowol3SeZkwVx9OhHLd-2X8Rs_jVWj1aTZyIcSsTOtc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'KAlFTH4S01IeRBdmQZrkirNTYQiXNIK0bmfLFL0bVLE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '8mcWv2bHbHv2HU89fyWe4Srf3csM-2F1LffZap_G_ts',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'oBtD2GRv4-8I142kvLlJFerMMbRPzLfudmOIhQUmVkU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0ubhm-gP3n1n7qqtYkXhOrfRH_2szuX1K4tbrsfw2_Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2rt26zZaSg2PnAgr_wa_hhdh7NsiiJaVGcukHXNypGk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sLnOvYSyZkKcIaQmK5A6SMoU883mOwbX44947rSDe40',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'gxr5w8qbRWCOetvDmviPqikHaSKHAq3NodA5uHRlWMU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '8NeNsky6zD3NzXLu1bzbsN7WveR4ZFbjTIM5Qi9ndok',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'S4n2HYUOg5bloACkJcqFx70Q0Lf31sRkW7APEX62pYo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'V_0zz7UzgSutRD2lz4AF9wLog-1dmsIyB_j7fBPm-7o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'MGdOkqNC7ZbP2dlaV3gkUVHpibzinozRLkFsb_vOfGQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kbh1h4M_50iUjutjL0xvdpm9zFi3S5vZgQZp0eTeMI4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'CjBEAaQACk3Pi0Bs6z8cFZWvAledD_s6qJu5Weg5OHc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FHMK-4RBBgkn-kUWtLfyb7qElBaeN9Wc_q5sX11skhY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kk9IF5tsXYyPAPhJSH44yIGtDW33TsBmXILEAlB-3yE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3zLxI9dBx5nhvQjoNSQioVm4OGDs0R-NZk3LQPisNec',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'uSi1If-hoBN-LZeKTaIIehzZ7UZPiP6_Q7weSre4CIk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zSo3hBXViI92v0SlaqJs4Hz_a0ULJyPea8ZU1TInmK0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VEIwzdorJLbALDTuPVgFVih35YB1aY83zxzATud9sto',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'i8v-DGxSu-J94EzsKTyVrbANPKUxN1Oald_xhe_T1BA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sHYajP7yAqR1Xx25sgLU8t-1jDljyVrQR0VLb6-Is1k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'xaJUz8HK0Ao9filAExnl3pG0cEOdyUVqNgsCSLnlz0s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Vzxa6OBLos417gMDYwzd9Dfj5RnX-QsoVQGCw4d2CHM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5WvovPIl-e7bTCzJgLHkB8NaEQAUZDybbuMASPAxmZk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '6DvR-qBrxaCmVQrTVXgOnSAfe3bjqABJeo1f9n-gVaA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PZ0fPtBh4_uQoKuyXY81wLtsZQVRaPMVRZWPESZJs1o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kpyyE52qpXNxow9ycZ2HOH7SKcr8aUEpAB7pH5Rct-g',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5DafPQiZgZTe2drrQnORZLbPuFXolPP_AsJgGxOgFlo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0YyVe2vrL-5p1nazzJ5KOG6byoXVsTKgCSchHfVgWeE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'enVyHtJhkbuCOh-GKFyP2hyFK-__xAEAo7PYApjmJ9A',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'XzRFGuoZqy65BdwUgG2KLTdjOONLoePnrSVPcVlb4mA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'mIBzasFLgQ9Ce6ig-opCd__Bjb-DXgtsh46KynKBeJg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'YG6z-EbQBYUMvgUpnwSg_jUAEi51wx8lcJJPPW1RkSA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'v2sCbm-AxrANfOoZvzp5vgb4MgBEfXh7OyqUQx38tr0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yF1Jhn3jvaxbgT1Tt_E-bNTWoneQ47L038LQI5AG3lo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Gv0T9PwaDVZ-93fbDT4bjXdyoDVSX-J8prNnV550LwM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jyP5xabtKAUG-3mW8EGz08dcWPs4frUHKuVYYeA8Iuc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'wWADbArlyezPcd87EJ9YnUmnYJMHH-yw-RWn-sdnKfA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'tK-rBGtJOi3puCJOwfmw835G_vfAHiwH0LpexU71svY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bikYEr8vT2PfJGPOhl5f1DgZY3wN7bxDWAWIHA5JKXo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'KA5j8Iy1h9ZWjmbNJyEXz-U8Qf8Xrw-BVB_8WoxeGr0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cIz4gMc2FiW3KSQkkEeVfgauNqvn_1Uh8u0mH-mOs7o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kRflejFs8zFN5VywQ3ObnUrEUCi55Ctyd3zWirTCmJA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'k8EcG5rddauDqtB2CkxxjX7f-09x3S4QhOiENXF4OMo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Z5MJ7nZzVuK23gT7TD2b_mMiLwyEjFsK1TWIM6aehVo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2bmvGAsikFek-GK3ON-yf_FumOZqliqvBbM545ZF6-Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'COTPR1Rd6CtQ1CNzFGhw7_NtbXiPL4SRY0VXnr8WVuU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'f3eljz05mReMo9l3ISC-daF5dsIrbZvhbzmHBXLrB-0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'dH4i4VGWCLD6MHk12rpE-bG2KB4I0H-XXCwAyETwN40',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EZ1sVSAMNLZK0zqfLGWW51rh9A_DXKrWZyW2vd3SfzI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'GYk7EzM92GFCUlb4mFFal9vYhoV4ux1V3TLlo0vixSE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FLfhSsEEi-Rbli5a08W5XkSiII2Ee5NRF-8ezQMh2iw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'HsSCSlzAog26EVRKx1LTNsorRDe-lyv3esWrt2OVFLw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VK5Oz1AWxBWfe1ORQiJU-I-B9rLbCeIXf7BdqdP7h0k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'HmWwu75xUOos65DhvnnjgoqKjm7d0bos1_eTSN4lelE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OkgzxxTtnnPiosjLjpg8DM-96SfO56kXOTyKpO8N7zo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '-mZmTKRyodLvCiS85cCtDGVh92WqvUjByW6mBZP-wY4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ljec9jpvX1lhP918aqrzX8BnmCNu1-s73qVzXRQWMfk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3f4Qqy4YjpiSuKuAjRPOI4SPk381z9bgqUSDDvGCJ08',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ohqa6ZoWckWBm6pRTDCm6u4cC9IBKpxwe0TVIMjGSxM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'G_DALS8jYghfUhVm5PI3zhHlo0VA0cC0-6zgVBNAYCs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'UNQLmEg9LL-2NYoYKoAa7DvrXqnQD83UFoviKJYkDS0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'r529yxc5ucydtIaiOXlX5CvpWH_unNJdZrAqs6g_6BU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'lMmBj9mPRSPIJTpBZ_WPvMLqsWd4qNxb279gB1xrJos',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sQJg0Ey5n2Iqaj7fuZLLXlMAcE_2rjZF2kND10iLUwY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '66iSTzJ1EYtCD0E9CT59G2Wfp2ZK2_zghy-Si5JdhPk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EhvUe-7c89IsabyAUvs_AdI-41usa5R828JckCinhZg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'j-xakoBOdGj1rD329YFPQHPgHeojpdFag89ti4aU4xg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PugouWcr62NHrqIlqw4WX2XsQ4Xnj8Zy_M-KkqiFXjc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9ilWnPT3cAdJCA0rV3YciboE9i4ev8Z6EfuNFFpyqo4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EiDzmHbiroTksWfYOu7BkHrSQITJbUIpdqpDenpYaFs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'dKXLbZ7WAH7igi8etI_OTNyat4wW5wAZmHr8_-j7hiA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'TPvb3lgr2vBbfVZ22J5Mx_LGxtd3oHapY-yXTw3hj8g',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'y3lVPJUum4ASUlSurtcpytzFOlrEAdl_VFf8GzoDkyc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'YE2Ml66ghcIoGsjaGvwO6dZs8typqO9qQml9Ig9WVjY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '36p6-j8nOr8owhcEQWtFQrNGUGx5J8ZaBwjthAdOUdU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vfluP-0rCHtJlDMq7y1AhT2J-xoMNmI29djJDVFXuXg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yxu3oyxGIPyS-zk27OTCOl976GOyuLFbPcitNjzBlYw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ROuRnGzlrFmm6mcshprs7LJyDIWlmtTpt17V3vyjjFE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'dF3H1Gkshw14juZCIRepHeNDOabbHvL_TrdnGZcvRXs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Z-_ZfNCO0mMxrWT86eH6No-nqzhcCJnWwDNAXCWTCKo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fGWjZn0iTXQsq0kpMqIn-xKrjoZ-mRA_rY0cq8Dd65c',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3956LTeX3lUDeNRkDtpf8-QglJ8q0l9MmAzbvZSAmOU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'NTYKesM5PF-TKiTM8PfZWJFsixg-vVGdCFen9geFLyo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Fu_qGFMKzmR0F53V7e-5VXSAaLqpi2T76JkhVfW0zGg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'w7mhhCmqFq7R8DQynu2SvhNzcrmJFdNDu9qEIzSH1nA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Exfnb7Y8i0uKB6YU7V9vs4ykqU3PusX8ZggsccWIZxU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZkHFz0jQJViNhy4mc0hQwUHHnmMKltA7QgSaT1srbcU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9ehZ-qiRykw68as6wrmVG7VPfru5QqNAAPs_v2pQMis',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '52adv_7DlUTZPZer8r_3JcfOiVweJp5bxVCzdZZ_B_4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Rx1stn8Krr1Zd6bnhNUen6IrGwwRtpwWf6dAOddrG6U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ap8s2C2VK3s76993IIBg2WPRwkd6p71xMx0JWa23gkA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'GPxvM000CGv5IprcaOtRm3YYEMOlK_wnBoOefVUsJxY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Je88hY5qGzMAEzf1myNrZPedD_CmckcsipqiER_B_c4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SqdIwuPfozoTPf3JdVv6OkvQ_MYxz0ZjhhW74thSSsU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '55dQIrR9-rJOz6Z7bQFm9ZeIle1YPtnZ0nCbDdzqulw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'CZc2tgmI9I0TEIyXNpgJOlX7aip4rYLIdfk8wyIQFMA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_g75czhRSL29kAercBuRoKAvtyyfCfDWmUMD3OmS8CE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '1HY1ltN675-xOwDjogVLMDAk0V5lIEdWkNo4UtUL-8Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '4gGXoRb2hPgOPv288Q-RklsSU0OTOLT0mFYLN163jHM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0I6z9WlGD3UDIvb1-wfWnDHnIoHkqynWZvdcqJGpsjk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hD5SUQk3dW-xwcvN2N6Qc47h1AGMNedGNdE079Zmgjw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'dQG78fqg7C832MCJ3Qm8wa3-TppdD5qXjqLFOvaL31E',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Xh9HrVqOqqVYNYUwgO9wNjp5-8YqIf5wSb_vvkMT5go',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'O654wQlcVYz2AZbFAism9n_V4XfrqbDqub5V3d4gaFA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZL4bfLl-fMLEZjGiAceDgCcU7yBL8Fv3CYrq0oWa4CQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vQ3pWPQ1CG8nJxZRQjygj3r4yowVFVPcSBQkPsGxabU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0culWGpzDqDzZ73YfSRtnLL8oz13mLJleKEpIlrR4rU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'y5J6cc60c4CsWahnlzIKpU2JXIn1NVgOF4dUm8tupek',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'BYfcsodkLX9-8dUPxVltOZIw93CwIpLEzkbNfwN6zUY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nb4pk3zBENQcBmypIN6zQfhWHmzbycwjYuzY7Fb9NzU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0Rd6qGGcRZ6BUmbx02VKMkWIN5Ls544YmAOHx83Pr-Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yKuwsOo0ml13L5ozbqJpTyfxUpN-urcYpXBhPJhxVl8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'AmRZR5hP7kPL1akX32jfSqhZGhZsgreSjYiOO6YZA1g',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'E3LfMuTpyhynE4VIzeWn956pD6XPejnnfk-Evx8cV8o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '4Et-Klg6FehLvYJfwZNZCGKN8EzbP5XO65KMzqGamAU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '4pPuYm5TAY39t5vJoB7eGPLL5QlSD9e9AM8o5jMm0w4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5OA-kCULQ106vQzZeTZvHRwUpOZ_IZaeR-f_uUdLKgw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'lzgpC8c493RbTC7x3o2z4w9GNwKX9KYyrX8-ly6vEDc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vuLz5AYaqVOAxQY_T3VXRQw2DRM6aHJ6w9M5m-3zhl0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'b3s1j_frcAlVvqrpDJvPeQTurxN7UFxyhNMi1Ez6tjM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cn6n4u48fdT3UatJfGEGsxUu_m858YbKMBplyyngzZg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'D6I5d7SKt1sH4zTfRITBjpmmn4TA-IiR-aHzRkBZmBA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WQJFyxPOti844jRdimFdtdMJl91CKk5fiq96qZX3RuY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'a8oETxguu7fLB9IfLEn38Z_pPEXfR4g6AweaRt0Lt3k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cDI3RVhJ6potLQqyxiC3_AG5ALsHY3KI42bxWQBYfjo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'm3XlrEHj1lkgGIxRt-IcGK1LVjG-KNXVIkkiS9DyZJo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'wfMfQeKqrB5QqJEZbWBuXsmGiwC1NjNy9mzC6XffahY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'R8MylS802xOuZv2irSvdD2zvZnA7Wjdi5jmoWkzqS7w',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fiBdM4TbVOWob2cMU0Z-RRKYHZbA2Vb5EiKyU0yTwmA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'C3f_Rl6WMDAo4yT2ijQAb9XOdbpLONrLqK2_DLmObBw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'IJivN-cBCjqI1pWtImzI2hXm_d2kcVX8Fk_jHAFL3xk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '-DqZeoSaYoUmxd276ZmtvZR1fDHGAOZE9LiQZSd-d8U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QpE2m_s7bDTuXeSGeeGS-sMfgW4wuz6NoOjBOSG6VP4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '30dftOvSSMjwvn9eJnR3YwFOOzGM_TdlD0QH8oXL41I',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Ud3eofthvIPYWC8mB-S-M6XMLdoV4BhZPY7wfOfj1tE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VcrGTpRtpwp7mcC1n-3MidFyEGiobHAvJ8zby1ROLuY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3DVCifva_LcYwYYZUv0Bcz7bxG7Zaszu9JrVn1bEUQE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'M8PCZi58zCwOEYkXeWIF4TCyEqcGapTeL5Ov6IRZhcU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'TReetMxoVsi4JhjskPAG2WvWciuP88YtLlkGQjuK5Rc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'P64TtCW8nbYFZLX91ikUi3J-VFA6qZrECWSZKF9eaR0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Rh2rzmsdQcAbPRaR6w1cgdxDep7vcOzavyeL7oJehRs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0hSm7OQA-6KilUeUXZ4pcXLwy_nBdA1mgLyGDZS3ClI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hmftMmvGA5RZdkEutiZmcGWSVbZEe7F_OD6L6uxRkUI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'oC6p4aFysI8Hscp___Gena1ojDjgXx-EYpxI2xmcQTc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '-yp6b_Zv_Kj_6XXgu35E4VJbycVRd6x6BR6bTh_8E4U',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'tpB90F5wxJGMJavQx8W6wfJc0E4R1nliBp8wHWzrKWg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sBXyhEaV40nuY9Zr2cN1ZxvsDkwTov5x1rodvcZOXWk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'I61JDi6u1jMELvfJaBFLtNidLKxTUXaKEkbT5cnt9po',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '-oeCIOwDzt1vIhsTIgX5V5XtInaSnsB4Y339wBDsYqE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '7jUhhD-l-KabF7-mR9HpXFEiD7CN1DsExltqBVAX5lM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WsRQfsA6dc-NblGET_tuzFnOKt6VSFGDLXrwNnszu30',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'B3rd41xxmCGuDGGr4i0FBVQrjbOY2KnX6JKdQppEvEQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kwyylmuShmLl5B7ZgpGQGQKKlZE3Uwy0M4e57wkBBUk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'T18d2_a1bfwwz4dbfd34LvMxaZM2ZBYCiPkT0wZ9cVY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'R-8jJs0c8aXBmIcjdyfxn2rMKxoMh3eKQ44t2PwrVMg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZFiDcuJMJkiyNjpCmlRX42ayqqMlyghxT7ZgwNMdOg8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'S1dTDhndpfmDi5jcOJAAp21CjE02sZUwnmQAS2DWhzI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5tprqgvB7Nal06CXwbWIYrrJu1-aZV8FlurSWwVlJ8E',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ybiiJziEgsahzpzhrJZVEdxkZ6uqnNkNn1Rg06vXN8o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '7KjexWHtte7zzvrGKcbae7eLU48HyYvLi5xvtUnS4Ws',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jeGWulCo-bodemwsDf6EBvF3E6waZ-bopgOjbwYiUiw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'LjSdH6e4ljR0FJejyGv8DHAv4_WWalT1KtOcnZy0UmI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'la-poMtfykRAA4EFhE1icAEY21sZEtqhM3tAUiAltV4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'prVHdOPalOG6c9nqXPvrPWJpOWmtgHdIt0LUYiOAPxQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Cmk8S2bN1XklQ9tdoGNaalSjtUNW7pzAEJZxxBLYPWI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'uUG2_5LOJ6sgRz-ldQYJ-V-qMIie3wQHH6zARY6snD0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'C1HqD1z5-o5e1JlodAIYqbFKiSSDQfKPgDv7K6F0r0s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'b2MEHPiNFeT49zkwpa5uCwap6xHewrKePKVWNvJGI8k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ixaEn_eyyTsnaTJdcataC09S2a-RuTmRzUnXbF6GiHM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'xuEtw2zykQuGhpZcA0__C8isq8n0eOfWgSVNEV3-700',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '6W8Y2AO8FkuAsO58vJitEPn17FV2PSzfJIypVb1-z5I',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QCENrAhbcjYGQ6cGYkvWUFT6mFKkIEQliJXSzoJq7qQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'O6JoA6NT72ztVp1SMRcd7W9Rlfb59xUEd0JANlE_eOE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5o5cIUBAjkOplehdtnkIf0Ti9mp9TZHefSnXCYbVct4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'K_RTaY25Rr3KMCpor1rP7wjfaVkChrQ1lwqqw-FTjHc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'byGO6L4pANTdAh7nkPkAIf1xXzSOD1pzyVwouYa97o4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'mB-fL3iQYik2Kq-jLWyN-qoJ0klVj6Iird1n9EtUqUk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QYYCzoEIws8DSRlG_llWrgZsAsqhwbxE16SEleDd0LQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'K2f-spTHfoaKdr_4K5L-XvaXOnv83jBrvvhmd5KaY6Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'u19MEhdzwv5z9g3Oko9NTinBLipCOVVwVtfYEgHeRtM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'QlU0KFyCv_SgBEzwUU-6HcVhHQG8HOs8C9-WqYRGus8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Njf8vcARg4zzt_Quz0WgZidj7JyluLC3FrGrPKwuobc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VASUVGZT4NhgZceNejZh6i6kY3jiCPGA_3EOFHfGlNI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EDABC7wfsYf77P6tE1MxDPKWMXyg-h06gUitzpW7hOM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0mcaIKg_KH1D6hvHPMOMQEW_IBN8aOzV1OhggLQOYYQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'iaTiiVxDKFDSyLx-H5wwvV_TUpJww_islSHX3H_mV1k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'CiZ4TJft11NSXsF8xpesSb2dSpnIJcVba8U19FOlPCA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'XOIdU7Nb26us4flyIhdE5coz2ujT2tLxTWcUrSB8HiY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'a-AOaAMzkLF3ATEsnf5YqqwAA_SKsTjZ3eViroWEgGw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZDiO6Qt_hWcCVp_nd03HJ-fWkuufqDjJmQmpDJjTBbw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'lWzq9QkOknepAghKDOnZVqEpxhqxI_gaSAvhf9PCQv8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Fx0M7Gg8LFe92eze828-B2PGVKWRAq7FoUA9hWDnAM4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '21bhjqJuZraHI8y-UKE9PrRkQLsSvDuoJ6zmkvFyFp0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PRkcuxKtDwMph5CxEbU5Qg_x00FN_KKPlXwCuye083k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'L4NlmcaJDOhryN2VVYl2ihuB2yHQ3WZJvMLLvj3uusg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'aQXP5xOgPcjh7Gov9T2QUSNj7wrIEU8942c8JXCH1tA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VV3dgUOeamQM9dzA_4o4_BpbDRaYAq3-Fvt6YdT8Jfw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ne1Eb7Q6btzPYdQ2KFroBo7UKRtl4rQvGLrXyf0qYZc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vmJ3I9t3D-SQajtcX5teHwQ1GfHQY-wGIi6qb_pKceg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'S02r5vHBrlpFcmn800KCXebIBRomfGEMx9B95giDsIw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'RBS-CJvcp74zT1WfygNPgTv2p48QWtGva4i8nWAOKCc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Zo9Ic3ZKJ83KXUFQnk_v0GYAvmH6OpRtCRb8zbovmag',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'duQkDU3qMeNldAEJRGBHf_-j8qbTToEaT6NfCqeXxSU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'O2oyhAjsGflZxsXxi6E2pTbXaYfOjkn9mG3XRDaPPXE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kI-xXwJeZMwBfuCEU3hL9BWPDI7UwjphiWC3tPwWymc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OxYMpjahZIgdA1S-ihmD7N5D4auzQzUA0G6_D8w8uGI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'H2FbiQ4SM29GUPqiPGZbhnvEV4C1ideWEy2Wh0JBI-0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'aI-pMJJKVRYcYxzLoB40Fg0Yy7zM6dxQsPDJNvB90eY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OE1rr_pYzAaL4eAk7Eho230ZhsC-Pth_cWCsbJOmQKA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'c3EBguep6LCOExVFzK7M0SgZ8n7mS-A3CaIagGR-7Oo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'pz0h9w5QnoSxW7anY4GyBXEm8wm75yTO_rOJO-rpxyE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'xUtBg-siZK5WDOEOqvWNSYgvG8pX64BfKgnKo-ZqpN8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'TRp_umoQryX8oQqDC2H7oGr2Pe8WtR7oSoex1Fz5q2Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nnE4WSST4-Lq_aaQy0CtM3S2k7tUr3bhwyDcSgEktmI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'IDY5yd_qeoq55ceeEN9BZpNvN3ekFl4Hja2dGw5z9sk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '5Bi6MAlIUVJENYXM4G7Ccf_ExbFCK0nKsThm88yDpHE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PIMzN1C2018jUe-cmzk40dBm31Yjw6qEhqtnjnZTm1Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PPkQhg7YrpBZGYSKNQMcLq3XnXcwUPIaxoCICEW80Xg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vuALRn8C6JiaVN_merkoPtPWOLJmEvzogwLp2fzEaHM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'JtJlEGtaojHQSilaV6HuFG2sz3OXytXxW92JL8KBa2w',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'A7UHwGhP7uwoKpoQ84w1qtqo6a13mq2x0pU1mL47ovI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0aiWAIRTap7NKZfkzz9dgfgMdVlMQN_KPHlNKSxT-0k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qvmREdPx1uhVTtQe2EBu1tBb22G1KUHyVmb6U38FYi8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cLP0LGPq6ykbAdt6Oi5l_vpsQoSkQpi_YkLaUURCgLY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3K11cBImq82PXFlkCQslrmxEvq0oPpJMhr8FBPHuaUs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fQI5x0-Ck6dy0pFL7a6bJkvLtbRyHG6HW-lbGmjCDs4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'mcDzaIwZ9ch2KRmVFMQUp1u5KCk0bRSUTNkowNzxF_s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bOJ_x0zy0D5mjPKxqmkqmxo5eNOZ-LxRHP3tomQDEmE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ANyjnW7tYusb32EG9AM75XV832hCg5iI-aAHJgaPTJw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fJsw_Bq619OJuKF2Zdg18R1FB-BjKtKf8eS0_kuUwXQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'LMmqCOXhCXzyT2WiHKIAEQM05qmfEx45qMYecbsjbu8',
#    'name': 'datapusher',
#    'status': 'revoked'},
# ...
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'JIAjq3vYNmVsVctSB5CFlxaJI3YcfwuwJZJ9KllEeis',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VVFpnMb3aP-BXYdMZ_kUx9Y-2O_ZQXvAObZUOtLDKjg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vEh547-pRNqev0eYaYJoVQ7-AZyF2VBh12BaQlDzUK8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'K8uuhXtOxAnKOpIdnqed-P4as_zwUk98WrIx0xZ4yaU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 's5yz2luI678NEDOISFDu7fbKRcpiLIw0ln5oLUWob1c',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'baexfAMqs6amhFPBhNmoALdTUQqDWZ5Whl8GD23bNaU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'euCgf5NELyoP_fvUYIAsyVf3X9cvO-CY74Bd9cxkMK8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'J8JvHs0UrXxE4d5BDhqzgMfxY4bHSpZK-mGB9-frxoc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '1N-4gJ-LqmjNKEtURMBJM1Al_3E17FjWPK-NcS8BZ2Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bqWmARbeULxrezn_LnRBI7E7_TguXeGI1agvTB8Z-OE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'LhshRIzcJkoXg899L_RjymEoF-ooFI1Mwsz6Cnl2fGk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SZrTOXOsTF2UAUYUrPJRQXhOQAikwsD7PktmrYVMir0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'GDm8f6tk0ivFgejH6Bmf4xUIF1O0JVattp8Vl7c14kg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SeWwS2V2Bjqdy88OyqPpHaUpFhOHsQCHB3MXoSUQ9pI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VTb4EToXdS3l7k3R1sShfrvCXH8qfEbGG8lEaim0l3c',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 's2Kg2y4dRm1XCG_L1NGaSdXyFaa7Zu1XQiqK5ILNXY0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Q1B3xiQ_f_w721CtTw0fzCCnkP_lMCQmokPFnP-Udls',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sesW6a_TM8UchnjDe8xtAFEoxKi2hqzBL5VrKhaC5p8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'gsw0sDF6kh5JzzjIpiLkW2NgsdkDeQXStXHMJvaxTWE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'LJZMF8Mdrlz0naQAiOz0qOaW-SFeyKfFZrcF3KzOMfc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '6ROJNq2sVZSPgc72gahe2TnD7WdBYLVUTZaWF_dqVxg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'poJXTSgwA-uk0wyqxXS6zs-CT3UqcsQFYPvnUlQfiWM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'GpF1H2_RF5r2VG_cX3lHxBi-rLCmteZkeQEJ2BfGMU8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OVtaVAo-A1V-S-fUbH9KSO9wF-Lf1uLGbQXpXH2o9aE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'dBk8Gdj0WZczj1-FA3L9B1okscrzEF9jKHBb1YzCGSI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'KsEM_mmU4O7gssZVcf4r97IWTZ_epZiTKJOQT8VInsk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cpVzbEeLrz9cKClduMoIPeyoSjqBczJYS6opSvemfV0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Dq6WUbJMa8kvRLUCy1TjM_e5rhn8MvycTAg_E46sYyU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zzZZz5ElDiriHPPbsoNxpCwoYBvlwv7OITjNT8vsMok',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '90PKI4l_u_73rrDU8D1bDYugjTqdVIla3jqw6MUNVgg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'EIscktO8WF0aHtdX7w2Gi7qV1OR5ueULkLjgYky22hs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zAdMJI-lrtKa9Trcl-D0VBf3uvr59BK2-UbyHXmQcsY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'mQCsiogeSjXMHxsnL6cCOR5oRFwCVLy9FKXiaIt4nqQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'TxDWSd_HhbIUcBqDh5dy_I-DvbY9H0Ahf3PvV6nbi9Y',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'RFnj8UnZXXUW0AnvWXc7NFXuoT7Liq7EQP1aBWsiQCI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VlxWcUD-pa0dSpFjrw2dD51iH8f4cFMOtXEatTGHDCo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'yzjZkJkLQTPZhdRZVRMfl9vQEALChCGr4KaZJnULwt0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'bQlaBV6AR7tzEnnKwFTbIPPBShpWsnnP0ZdfOTSdL6E',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'gS52rXdlt1Kv44HfQNSeBjOjRBX4vgTm_GYsatCaUIY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'exRH3_rE9tHM0T4V1cwLMAzSjb3qcJXUCfJ1d1bxeic',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'KeMjCROoGunfNAI6g6cOm1tzP7ZKbKk5Nhg0GHhdoio',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qRbC8wkCwMYaeRAG-jso8Y-6kI6hf-uhxSEujeuKIv0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SLJI4x-Ajd5E9m48em-s4MMpNxIQtxeRmauzEKJsoKQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'pzJueo1400BNd8MpiUgQ_FsAxEOfpcbd43rTVqW6lUo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'T6vaSTkRYLsY6dVqvtmMvPLLUSYJP_JMc9OV61NXPUI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Av1v7CcWIwR-raGOOTjUQhIamcNhUHhyMRfEB3tg6H4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'D6YS0CEBukYgCrR-R0HokAOEbgitNn4Y3fQHgaBjZ84',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SrH51mC635rfndjyJJbPZOaBgaDx9zCy4-NFIF-JgeE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'pZeltjpWlMf-mP47gzXhVBkADpnhSXmbGvGZzMQ9YxI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hcDFjYAOCymUwQWcDsFwub_FpxHn8-b4JdPU3jZReVM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZLXsQIX6swAWAFc3r3KoELn19-Jgo1hxaqnDgOSJrYA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'M6uZOmo8mR7l5uP0op-ypmJMVLs8m8MiHu0AnxNlK-o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'GUD4PKhp8gqANc2QiBPThKWzWrd3Mokd0tBbm0N0_tg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'z7Ysg1FDUSbM0HtKcOvAcFPRRHF-kgqnvBjh6bFmajY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'aT0lirxVHbYAfQ1TAQ21j6pmnYFN1K_YEsE9oehg9u4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'w5ukVFs8B_qY11Gil2ygenDMUvvC6HKL6wqsgfcjiwI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WQ0D9HgZ6onId7VXPzm7cvIdbkynm5TxH0OJAuz9Clk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Y3A17LGeY6eMm4_iREkg6KFGjJXEM0TLKuGHJGGItic',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'VsH3hgHfAFTkCnpG23r84yz09xJ3pOuEJA9yYv6BeDc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'GVaAbcZ7ONCfmS84S40amF-M_32NEpmYd-XhzfbzgSw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vjrZp7npgh2C0wlIPr0NuOXHh8csyVWaVw2ujXz6Oh0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FpQSqaMAkQPrt4vhBs9xT2DIXeXs-NAI-iDMxumXs0o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nbFnwsOd4TEe96va0oSOEnnfTW5Ouw2FJoFdQw8O3VM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'DlRSZwl9nb14C96__4hczfYr9htQ2A9sSc-XzIDRyjc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qW3WuX0yLyJ76MHaZHCuuUnuYpfj0mcViCct7bbZqtU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '_XMHPYBIlhiYXkFm3smQLEFQsMfZhAqTvw62g09Au4w',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'y0kl9b2yFoQw8O361v-oKGN5IYzMgH8tW5DPIOS7UtM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sPiWgYBNa4zNG-sV9qM9g-N8Q1oyqxiD-Id-LgcaHRk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FfmkHxObvIRfn48zdHJeK1iH1ycnLG4zXDR8xU5mNys',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZafWvfIP7VDLsT7GDOPofIUKIaasxVRy1V2WDcDrato',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'PnB2j8k6ubtBU3WmbPfCm3bDxVpx2n6bhcPLJ5akSYs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'scfTXnVKlWpNivzTEQDDtuKAncXP7Tw_wRj3uiOA0gU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jq0fBC9CjtJjSKkIscccIdzgklqUAROeJQqUI8n-ZBM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'zBGkzYakWXoEbn63pWEJuueqG6r3PPFsA5xfUlrHcNM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2l3dEFV1ZPeGYZPSXWmxfma3SqR1c1WC66GjdeTsZG0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'RymBzLgF2rZcs9Z5xesuSlbAbbVDZQwa2WFfXaFvy14',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '-XAbqGi05gWUjaAaB1-eHSweIawESyJSmqNZsEBrRYg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'b4cJ3l04OYIedCV2Y6IKpzAtq4Y1lvMgF1nIHEVoYTo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'sCOC7UbFVIkVbEaiYKrXb_g_mLClATO8nIlYMNO5gWQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '2DRUBnf8kqS7K563qe-1tvykPHuTTKcFZ-kZ7iTv2Vc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '1K35ew_RB9xJEnmQlXdK69q30Tx5v2FuBeBwfcbutPk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ziWA7WhYy3Qjo2-uZzDZDZj-s-WpEgsICFf2TI22RRk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'm8GCkvrX5JejLJhXW-JuaSCZqlzSykXm_I77MRrBcto',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'hc0ptGi5cRM7qCU3FMqU4fDALgztJ_REQwH1ySpf-cg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Z_J4Wb8d1MUv1zKRbFtxzEieFzBqDfJViTGJdwzD3XA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZhNV2UNbFenPVdUTa_tqAAwLOf0prV7yMUdapcueIJQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'NreQCFznsE-qoc-tk75snvhlvBn6yexoDxqi0pO3XNk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nAxggtZBmo9xGgwKrMK9ehRnpg6J4OBHX8AjFrWV0rA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'de9tKoNQcxxmm0n7RfgJ1hYb3QXQwpb6Az3FgAp8rp0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'I4I5lYMC3mWZbajdcD5fA1UZX2sQRYpd_6U1MsUzFbo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'G6u-B1nBvMT1V9nALvT_GsMNb0XUWD7gU-JYeVw42KI',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'OG9aDpym8AhLmk-nlGCs1cQkbtM3hB7vYWz_wJBqTU4',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'k8eyvUKJJQ2JZLWBAP2iCLn7o55MrFlBVyXBJYQ6xCU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'k2tF0JZLjvSIRrX3uij1gUgzuT2RZ1g_Kj7tAwZ2wBQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vWcxdinO86MrHI8Kzpoq0Xuv9mGS07XYlVh5KAzXzug',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Ys3-pV7H4sXMGj4uOmy1sPKWlo39cPOMMIQa19cYC7A',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'T62hVDIueJdWqm5trSFATGbPpJlbOwe39eaYqQjQLbg',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'A1S1f80zPVwHek1kIVeoLSKZUhvkxLkfRuRUv6dBYoE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'klF121I6sdB_98js27xTtuKQEoagAlTSEW05PJp4By8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9P6VSBz50pred1YHUBWM4AJ5-4GDCNUdoDPCmiIV8UQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '6s8Cafj8h_oiwWQtu36N3Kp4fbNpAao5dHMdteflCvc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'lLQ_y0kYtvGhqKQsMnv6D1N58HrlcMK01Kuc2EdcNDs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '9Cjx8DqHN_fvdHVC_SlUSop-XlMnHEo4hxWqYyBvPFY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'a4KuSNi8FpNzqF1wCHJqiS678ZtDn1poA1-cpIoZCnk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ie1ksdTY3cwJC8r0xD_bvtX0V9DkbHkgLVb5Bwa7xOA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'XxbRBtWKzu1vOx7J1cWJDcqkVnJAVadVjZ1leTiBut8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '6ZpuR9nLo8Vlwf7UNJw_t-UhWzcpcfLVD3XdQZ70vJc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'IDQmV1IJ_dJY1L0GrMkSOi_4o1H13OL_x8bPfN_6Fck',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'YOgT8unQ8v1EiOnY45IwvPJ7Et6RMiuFWGGR6X0iA0o',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '7bth7ylKrXjtX3u4VeDWbBKxd2j30-DFoaX4oqs5Uyo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'JlsuoyIghruqjSBDhjf5bq4UdWIKeUDBtPstvDRPZu0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '7PlpBjh4eFPNqCu8b7ssoniU0tNwAK2iMHSLGbb_iiY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'WHl_scz5_p8Wc72JmLznJyQQXqKXOpgNwTyS69j1wwY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'fj3iJnqZoMME4LrOZ-2_sG52Z9CblDD_AkrHPgxDAYs',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '47bdUPHLkQlNgQ9BEfiqjJvsVyqPHuQBqwsjFAuWBSc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'v232iJGvmsPCs9eRnylPza2-w0WItHo2uzRkOnCqw-s',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '05HcA_Ac7n8L7fXSskXdUBTcbnQrJQAm36sq2bs2FN0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'jWhxbtrqAX4Ayzng31hP4tpR82T7Cj77RRcGyLH3cHE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'eQlnZVr-8qrYWGtIz54q8EUKB37e0c6QC2R6Lu8Z3PQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'qFtK_XuhvJ8-pTw8G8I1x4lsTZZP0bwkD4BbpR2RlSA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'kGx_a7dSw27fCzPieozM_9THpO6MvbTKrjAuc80NmwQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0kbTYBu3rtZgsjM0GY1LoS5HSPvEejvHgKVttazz_sU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'm36LGiUjPauICpNwqSslPcFtPVinvgYbuvhrhWHws1Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'ZmRUFcoyEZc4BGVluHxR216Pv9epcPyYFMeR_HVQaaU',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'A3yja688CLpFFN7_uRaVj2OY6Dh0X4IQilquzwPsT9k',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'wUj-_UswnaIlY0g4b-ZXGF8jO6aKeios0vjEdgeyY1M',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'v3SLTFUtvYDVvipFT0gNdfTAIL_bKWANKAOs4fBrwP0',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'Yvd8-9MPV7G-XbWziOowklPYeUmiZE_VIle3l3G_4iE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'lmldEZ474FF9d30XUOi3c4_-DhUGwGYUMDI2BCj8ukQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'XwVW1DDSeofeWLwgzW6EoocbGhlvJ7-QkUXFZzeD_Ew',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '3wgPJxWNJKPYLfj5siid3ANQ2puYoywaKxd0IFTFbVE',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'xL_pwxlzTBYz6l3TToudkkiLc0PMzWq7FDxTfiM5uiA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nUw3UW-FXf0I_PMOhwowlmE0Ic9gCIeun0Jhg0U4ghw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'vOaXMkemkKOQGCRvg_sGXYpjSV6CYTcPMEbyP7j8B4w',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'aNhgd0Dvn97z6r_gX62ydBK-fHzax3XR1FrBmzuWwuk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'j_QitxzfOuNt-oN-rZ5ERANByBhjFzUY4ndX-m0NYys',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'FRnaNKh2Llztq7QasCHc4MEqZ2wvkJqyrN7IW79xIGw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'tZ9GFeBw5fGRTUePxXtyHNBBIP9CpWC3QfExUh8kQVc',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'g7cG4Ij5EAadcgsYukBYxgYVJp_dCoqov8IcwLDZTk8',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'JTiK1FcYccZ3YuO5ThZr49mDv926NKB-CACMTP-opVA',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'n85WQ3XxkcpCo9wMN9W6GjDAM5d_xfRFC9_Q5-Zo4Wk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'cbEMSkqDgrRtGZZg1elkezLfSHzgH2Ajf5rOWU2fMmQ',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'g8hnNwhwhuZhJY_0Ercw5Pp6ZcEVisYCPg7l0l0LUKw',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nvfdHj5EnNheJkcT7gZwSSZujZF0jYeG1Q7RRso5pfk',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '0hucf_dZwCalehC5Rii0-3O0mIq3nohThetNiXLF23A',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': '7wg3giGP64k4L3EpCyR-F1zq-nK281HRWYdLxDGmB2Q',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'AEV1SJKVkunUQUQsjUD23-VUd8EH1-Rbbigzf8eInEM',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'nn0Dui14mtBFREgUIVJ8xLXJ90HSoMML0-fn1evKbsY',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'MSoH_H6pCU18Cd1XXTPcE02EVg87K7dBHkAU0eBC-Jo',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   {'id': 'SII-hgQkkdYZcjNIbKmFr0-AUAg93otkyh2fINH3J9M',
#    'name': 'datapusher',
#    'status': 'revoked'},
#   ...]}

# %% [markdown]
# <center><h1>Advanced</h1></center>

# %% [markdown]
# # DataStore
#
# Push a resource (e.g. attached csv file) to datapusher

# %%
def datapusher_submit(*, api_key: str, resource_id: str) -> dict:
    """
    Trigger CKAN DataPusher to (re)submit a resource for processing.

    Equivalent to:
      POST /api/3/action/datapusher_submit
      JSON body: {"resource_id": "<id>"}
      Header: Authorization: <api_key>

    Notes:
    - Typically requires a sysadmin/admin API key depending on CKAN/DataPusher config.
    """
    if not api_key or not api_key.strip():
        raise ValueError("api_key is required (often sysadmin/admin for datapusher_submit)")
    if not resource_id or not resource_id.strip():
        raise ValueError("resource_id is required")

    payload = ckan_action(
        "datapusher_submit",
        method="POST",
        data={"resource_id": resource_id.strip()},
        api_key=api_key,
    )
    return payload


# Example usage:
# result = datapusher_submit(api_key=CKAN_API_KEY, resource_id="xxxxxxxxxxxxxx")
# print_key_vals(result, num_keys=20, num_records=1)

# %%
result = datapusher_submit(api_key=CKAN_API_KEY, resource_id="0fa3fb1b-857b-44d5-91d7-46d510af627f")
print_key_vals(result, num_keys=20, num_records=1)
# Out:
# Record 0:
# {
#   "help": "https://instrument-test.data.auscope.org.au/api/3/action/help_show?name=datapusher_submit",
#   "success": true,
#   "result": false
# }
